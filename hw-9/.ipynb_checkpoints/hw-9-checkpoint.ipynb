# %%
import numpy as np

from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.layers import Reshape
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.regularizers import l2
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255.0
val_images = val_images.reshape(val_images.shape[0], 28, 28, 1).astype('float32') / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255.0

print("Shape of train_images:", train_images.shape)
print("Shape of train_labels:", train_labels.shape)
print("Shape of val_images:", val_images.shape)
print("Shape of val_labels:", val_labels.shape)
print("Shape of test_images:", test_images.shape)
print("Shape of test_labels:", test_labels.shape)
# Out:
# Shape of train_images: (48000, 28, 28, 1)
# Shape of train_labels: (48000,)
# Shape of val_images: (12000, 28, 28, 1)
# Shape of val_labels: (12000,)
# Shape of test_images: (10000, 28, 28, 1)
# Shape of test_labels: (10000,)

# %%
model = keras.Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_73"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_80 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_80 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  conv2d_81 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_81 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  flatten_73 (Flatten)        (None, 1600)              0
#
#  dense_181 (Dense)           (None, 128)               204928
#
#  dropout_107 (Dropout)       (None, 128)               0
#
#  dense_182 (Dense)           (None, 10)                1290
#
# =================================================================
# Total params: 225034 (879.04 KB)
# Trainable params: 225034 (879.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 80
epochs_adams = 50
batch_size = 100
batch_size_adam = 160

optimizer_sgd = SGD(learning_rate=0.005, momentum=0.9)
optimizer_adam = Adam(learning_rate=0.001)

model_sgd = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(140, activation='relu'),
    Dropout(0.2),
    Dense(180, activation='relu'),
    Dropout(0.1),
    Dense(10, activation='softmax')
])

model_adam = Sequential([
    Conv2D(40, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(80, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(160, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

model_sgd.compile(optimizer=optimizer_sgd, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_adam.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_sgd = model_sgd.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(val_images, val_labels))
history_adam = model_adam.fit(train_images, train_labels, epochs=epochs_adams, batch_size=batch_size_adam, validation_data=(val_images, val_labels))

loss_sgd, accuracy_sgd = model_sgd.evaluate(test_images, test_labels)
loss_adam, accuracy_adam = model_adam.evaluate(test_images, test_labels)

print(f'Точність моделі з оптимізатором SGD: {accuracy_sgd*100:.2f}%')
print(f'Точність моделі з оптимізатором Adam: {accuracy_adam*100:.2f}%')
# Out:
# Epoch 1/80
# 480/480 [==============================] - 3s 5ms/step - loss: 0.9355 - accuracy: 0.6645 - val_loss: 0.5466 - val_accuracy: 0.8110
# Epoch 2/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.5634 - accuracy: 0.8004 - val_loss: 0.4601 - val_accuracy: 0.8332
# Epoch 3/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0.4949 - accuracy: 0.8246 - val_loss: 0.4355 - val_accuracy: 0.8407
# Epoch 4/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4579 - accuracy: 0.8367 - val_loss: 0.3977 - val_accuracy: 0.8556
# Epoch 5/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0.4345 - accuracy: 0.8433 - val_loss: 0.3895 - val_accuracy: 0.8565
# Epoch 6/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4120 - accuracy: 0.8510 - val_loss: 0.3844 - val_accuracy: 0.8586
# Epoch 7/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4019 - accuracy: 0.8553 - val_loss: 0.3675 - val_accuracy: 0.8649
# Epoch 8/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0.3873 - accuracy: 0.8602 - val_loss: 0.3618 - val_accuracy: 0.8685
# Epoch 9/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3756 - accuracy: 0.8640 - val_loss: 0.3551 - val_accuracy: 0.8703
# Epoch 10/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3672 - accuracy: 0.8670 - val_loss: 0.3538 - val_accuracy: 0.8698
# Epoch 11/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0
50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2493 - accuracy: 0.9327 - val_loss: 0.2956 - val_accuracy: 0.9150
# Epoch 22/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2429 - accuracy: 0.9351 - val_loss: 0.3119 - val_accuracy: 0.9108
# Epoch 23/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2414 - accuracy: 0.9357 - val_loss: 0.3042 - val_accuracy: 0.9147
# Epoch 24/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2385 - accuracy: 0.9367 - val_loss: 0.3086 - val_accuracy: 0.9136
# Epoch 25/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2343 - accuracy: 0.9394 - val_loss: 0.2970 - val_accuracy: 0.9176
# Epoch 26/50
# 300/300 [==============================] - 12s 38ms/step - loss: 0.2302 - accuracy: 0.9401 - val_loss: 0.3079 - val_accuracy: 0.9155
# Epoch 27/50
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2298 - accuracy: 0.9406 - val_loss: 0.3089 - val_accuracy: 0.9122
# Epoch 28/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2219 - accuracy: 0.9442 - val_loss: 0.3034 - val_accuracy: 0.9151
# Epoch 29/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2222 - accuracy: 0.9443 - val_loss: 0.3085 - val_accuracy: 0.9168
# Epoch 30/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2204 - accuracy: 0.9442 - val_loss: 0.2961 - val_accuracy: 0.9183
# Epoch 31/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2195 - accuracy: 0.9456 - val_loss: 0.3202 - val_accuracy: 0.9118
# Epoch 32/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2156 - accuracy: 0.9465 - val_loss: 0.3130 - val_accuracy: 0.9139
# Epoch 33/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2107 - accuracy: 0.9495 - val_loss: 0.3038 - val_accuracy: 0.9179
# Epoch 34/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2084 - accuracy: 0.9503 - val_loss: 0.3017 - val_accuracy: 0.9171
# Epoch 35/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2083 - accuracy: 0.9504 - val_loss: 0.3070 - val_accuracy: 0.9183
# Epoch 36/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2031 - accuracy: 0.9529 - val_loss: 0.3154 - val_accuracy: 0.9158
# Epoch 37/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2038 - accuracy: 0.9519 - val_loss: 0.3141 - val_accuracy: 0.9173
# Epoch 38/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2006 - accuracy: 0.9532 - val_loss: 0.3264 - val_accuracy: 0.9141
# Epoch 39/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2022 - accuracy: 0.9521 - val_loss: 0.3074 - val_accuracy: 0.9172
# Epoch 40/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1965 - accuracy: 0.9540 - val_loss: 0.3103 - val_accuracy: 0.9188
# Epoch 41/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1961 - accuracy: 0.9554 - val_loss: 0.3203 - val_accuracy: 0.9192
# Epoch 42/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1946 - accuracy: 0.9552 - val_loss: 0.3396 - val_accuracy: 0.9118
# Epoch 43/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1895 - accuracy: 0.9593 - val_loss: 0.3230 - val_accuracy: 0.9138
# Epoch 44/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1900 - accuracy: 0.9576 - val_loss: 0.3223 - val_accuracy: 0.9174
# Epoch 45/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1882 - accuracy: 0.9574 - val_loss: 0.3161 - val_accuracy: 0.9180
# Epoch 46/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1867 - accuracy: 0.9583 - val_loss: 0.3305 - val_accuracy: 0.9198
# Epoch 47/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1848 - accuracy: 0.9604 - val_loss: 0.3296 - val_accuracy: 0.9193
# Epoch 48/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.1835 - accuracy: 0.9603 - val_loss: 0.3311 - val_accuracy: 0.9157
# Epoch 49/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1787 - accuracy: 0.9627 - val_loss: 0.3356 - val_accuracy: 0.9157
# Epoch 50/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1836 - accuracy: 0.9606 - val_loss: 0.3399 - val_accuracy: 0.9156
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8867
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3580 - accuracy: 0.9105
# Точність моделі з оптимізатором SGD: 88.67%
# Точність моделі з оптимізатором Adam: 91.05%
