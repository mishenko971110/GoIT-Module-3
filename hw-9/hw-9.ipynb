# %%
import numpy as np

from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.layers import Reshape
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.regularizers import l2
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255.0
val_images = val_images.reshape(val_images.shape[0], 28, 28, 1).astype('float32') / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255.0

print("Shape of train_images:", train_images.shape)
print("Shape of train_labels:", train_labels.shape)
print("Shape of val_images:", val_images.shape)
print("Shape of val_labels:", val_labels.shape)
print("Shape of test_images:", test_images.shape)
print("Shape of test_labels:", test_labels.shape)
# Out:
# Shape of train_images: (48000, 28, 28, 1)
# Shape of train_labels: (48000,)
# Shape of val_images: (12000, 28, 28, 1)
# Shape of val_labels: (12000,)
# Shape of test_images: (10000, 28, 28, 1)
# Shape of test_labels: (10000,)

# %%
model = keras.Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_76"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_84 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  conv2d_85 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_85 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  flatten_76 (Flatten)        (None, 1600)              0
#
#  dense_189 (Dense)           (None, 128)               204928
#
#  dropout_112 (Dropout)       (None, 128)               0
#
#  dense_190 (Dense)           (None, 10)                1290
#
# =================================================================
# Total params: 225034 (879.04 KB)
# Trainable params: 225034 (879.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 80
epochs_adams = 50
batch_size = 100
batch_size_adam = 160

optimizer_sgd = SGD(learning_rate=0.005, momentum=0.9)
optimizer_adam = Adam(learning_rate=0.001)

model_sgd = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(140, activation='relu'),
    Dropout(0.2),
    Dense(180, activation='relu'),
    Dropout(0.1),
    Dense(10, activation='softmax')
])

model_adam = Sequential([
    Conv2D(40, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(80, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(160, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

model_sgd.compile(optimizer=optimizer_sgd, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_adam.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_sgd = model_sgd.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(val_images, val_labels))
history_adam = model_adam.fit(train_images, train_labels, epochs=epochs_adams, batch_size=batch_size_adam, validation_data=(val_images, val_labels))

loss_sgd, accuracy_sgd = model_sgd.evaluate(test_images, test_labels)
loss_adam, accuracy_adam = model_adam.evaluate(test_images, test_labels)

print(f'Точність моделі з оптимізатором SGD: {accuracy_sgd*100:.2f}%')
print(f'Точність моделі з оптимізатором Adam: {accuracy_adam*100:.2f}%')
# Out:
# Epoch 1/80
# 480/480 [==============================] - 3s 5ms/step - loss: 0.9231 - accuracy: 0.6664 - val_loss: 0.5605 - val_accuracy: 0.7981
# Epoch 2/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.5636 - accuracy: 0.7993 - val_loss: 0.4675 - val_accuracy: 0.8319
# Epoch 3/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4911 - accuracy: 0.8242 - val_loss: 0.4271 - val_accuracy: 0.8422
# Epoch 4/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4553 - accuracy: 0.8359 - val_loss: 0.4059 - val_accuracy: 0.8522
# Epoch 5/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4322 - accuracy: 0.8455 - val_loss: 0.3826 - val_accuracy: 0.8594
# Epoch 6/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.4140 - accuracy: 0.8509 - val_loss: 0.3778 - val_accuracy: 0.8622
# Epoch 7/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3962 - accuracy: 0.8563 - val_loss: 0.3653 - val_accuracy: 0.8664
# Epoch 8/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3858 - accuracy: 0.8609 - val_loss: 0.3674 - val_accuracy: 0.8673
# Epoch 9/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3765 - accuracy: 0.8639 - val_loss: 0.3558 - val_accuracy: 0.8693
# Epoch 10/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3666 - accuracy: 0.8665 - val_loss: 0.3508 - val_accuracy: 0.8696
# Epoch 11/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3585 - accuracy: 0.8711 - val_loss: 0.3443 - val_accuracy: 0.8737
# Epoch 12/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3500 - accuracy: 0.8737 - val_loss: 0.3407 - val_accuracy: 0.8744
# Epoch 13/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3427 - accuracy: 0.8765 - val_loss: 0.3332 - val_accuracy: 0.8788
# Epoch 14/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3327 - accuracy: 0.8784 - val_loss: 0.3354 - val_accuracy: 0.8786
# Epoch 15/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3312 - accuracy: 0.8799 - val_loss: 0.3305 - val_accuracy: 0.8785
# Epoch 16/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3248 - accuracy: 0.8809 - val_loss: 0.3331 - val_accuracy: 0.8778
# Epoch 17/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3173 - accuracy: 0.8833 - val_loss: 0.3241 - val_accuracy: 0.8812
# Epoch 18/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3116 - accuracy: 0.8865 - val_loss: 0.3228 - val_accuracy: 0.8823
# Epoch 19/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3084 - accuracy: 0.8864 - val_loss: 0.3379 - val_accuracy: 0.8754
# Epoch 20/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.3036 - accuracy: 0.8886 - val_loss: 0.3208 - val_accuracy: 0.8839
# Epoch 21/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0.2984 - accuracy: 0.8900 - val_loss: 0.3291 - val_accuracy: 0.8842
# Epoch 22/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2966 - accuracy: 0.8889 - val_loss: 0.3270 - val_accuracy: 0.8830
# Epoch 23/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2914 - accuracy: 0.8922 - val_loss: 0.3242 - val_accuracy: 0.8832
# Epoch 24/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2913 - accuracy: 0.8907 - val_loss: 0.3216 - val_accuracy: 0.8837
# Epoch 25/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2853 - accuracy: 0.8939 - val_loss: 0.3149 - val_accuracy: 0.8876
# Epoch 26/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2843 - accuracy: 0.8951 - val_loss: 0.3234 - val_accuracy: 0.8830
# Epoch 27/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2800 - accuracy: 0.8962 - val_loss: 0.3104 - val_accuracy: 0.8888
# Epoch 28/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2774 - accuracy: 0.8979 - val_loss: 0.3133 - val_accuracy: 0.8857
# Epoch 29/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2751 - accuracy: 0.8981 - val_loss: 0.3119 - val_accuracy: 0.8859
# Epoch 30/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2728 - accuracy: 0.8986 - val_loss: 0.3173 - val_accuracy: 0.8852
# Epoch 31/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2664 - accuracy: 0.9010 - val_loss: 0.3098 - val_accuracy: 0.8866
# Epoch 32/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2652 - accuracy: 0.9020 - val_loss: 0.3131 - val_accuracy: 0.8872
# Epoch 33/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2614 - accuracy: 0.9030 - val_loss: 0.3144 - val_accuracy: 0.8861
# Epoch 34/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2604 - accuracy: 0.9025 - val_loss: 0.3166 - val_accuracy: 0.8872
# Epoch 35/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2557 - accuracy: 0.9038 - val_loss: 0.3085 - val_accuracy: 0.8908
# Epoch 36/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2556 - accuracy: 0.9055 - val_loss: 0.3136 - val_accuracy: 0.8882
# Epoch 37/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2518 - accuracy: 0.9078 - val_loss: 0.3143 - val_accuracy: 0.8888
# Epoch 38/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2475 - accuracy: 0.9070 - val_loss: 0.3104 - val_accuracy: 0.8897
# Epoch 39/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2467 - accuracy: 0.9069 - val_loss: 0.3110 - val_accuracy: 0.8892
# Epoch 40/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2449 - accuracy: 0.9076 - val_loss: 0.3167 - val_accuracy: 0.8871
# Epoch 41/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2454 - accuracy: 0.9088 - val_loss: 0.3127 - val_accuracy: 0.8891
# Epoch 42/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2411 - accuracy: 0.9101 - val_loss: 0.3150 - val_accuracy: 0.8892
# Epoch 43/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2402 - accuracy: 0.9097 - val_loss: 0.3079 - val_accuracy: 0.8894
# Epoch 44/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2369 - accuracy: 0.9110 - val_loss: 0.3144 - val_accuracy: 0.8892
# Epoch 45/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2380 - accuracy: 0.9118 - val_loss: 0.3124 - val_accuracy: 0.8896
# Epoch 46/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2313 - accuracy: 0.9141 - val_loss: 0.3194 - val_accuracy: 0.8875
# Epoch 47/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2295 - accuracy: 0.9131 - val_loss: 0.3151 - val_accuracy: 0.8917
# Epoch 48/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2309 - accuracy: 0.9133 - val_loss: 0.3130 - val_accuracy: 0.8912
# Epoch 49/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2301 - accuracy: 0.9143 - val_loss: 0.3292 - val_accuracy: 0.8875
# Epoch 50/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2262 - accuracy: 0.9146 - val_loss: 0.3086 - val_accuracy: 0.8913
# Epoch 51/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2217 - accuracy: 0.9158 - val_loss: 0.3145 - val_accuracy: 0.8933
# Epoch 52/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2234 - accuracy: 0.9156 - val_loss: 0.3149 - val_accuracy: 0.8915
# Epoch 53/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2194 - accuracy: 0.9181 - val_loss: 0.3243 - val_accuracy: 0.8881
# Epoch 54/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2207 - accuracy: 0.9181 - val_loss: 0.3208 - val_accuracy: 0.8908
# Epoch 55/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2159 - accuracy: 0.9186 - val_loss: 0.3267 - val_accuracy: 0.8895
# Epoch 56/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2186 - accuracy: 0.9182 - val_loss: 0.3311 - val_accuracy: 0.8871
# Epoch 57/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2161 - accuracy: 0.9191 - val_loss: 0.3099 - val_accuracy: 0.8900
# Epoch 58/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2133 - accuracy: 0.9195 - val_loss: 0.3195 - val_accuracy: 0.8915
# Epoch 59/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2116 - accuracy: 0.9200 - val_loss: 0.3263 - val_accuracy: 0.8873
# Epoch 60/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2109 - accuracy: 0.9215 - val_loss: 0.3167 - val_accuracy: 0.8904
# Epoch 61/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2088 - accuracy: 0.9219 - val_loss: 0.3205 - val_accuracy: 0.8896
# Epoch 62/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2074 - accuracy: 0.9219 - val_loss: 0.3163 - val_accuracy: 0.8890
# Epoch 63/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2059 - accuracy: 0.9226 - val_loss: 0.3250 - val_accuracy: 0.8900
# Epoch 64/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2062 - accuracy: 0.9226 - val_loss: 0.3208 - val_accuracy: 0.8895
# Epoch 65/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2030 - accuracy: 0.9233 - val_loss: 0.3182 - val_accuracy: 0.8923
# Epoch 66/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2010 - accuracy: 0.9239 - val_loss: 0.3201 - val_accuracy: 0.8918
# Epoch 67/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.2014 - accuracy: 0.9239 - val_loss: 0.3238 - val_accuracy: 0.8897
# Epoch 68/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1997 - accuracy: 0.9243 - val_loss: 0.3359 - val_accuracy: 0.8868
# Epoch 69/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1997 - accuracy: 0.9246 - val_loss: 0.3187 - val_accuracy: 0.8928
# Epoch 70/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1969 - accuracy: 0.9268 - val_loss: 0.3302 - val_accuracy: 0.8882
# Epoch 71/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1946 - accuracy: 0.9268 - val_loss: 0.3288 - val_accuracy: 0.8896
# Epoch 72/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1926 - accuracy: 0.9273 - val_loss: 0.3300 - val_accuracy: 0.8917
# Epoch 73/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1956 - accuracy: 0.9271 - val_loss: 0.3353 - val_accuracy: 0.8879
# Epoch 74/80
# 480/480 [==============================] - 2s 4ms/step - loss: 0.1919 - accuracy: 0.9281 - val_loss: 0.3211 - val_accuracy: 0.8919
# Epoch 75/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1960 - accuracy: 0.9265 - val_loss: 0.3157 - val_accuracy: 0.8928
# Epoch 76/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1891 - accuracy: 0.9292 - val_loss: 0.3258 - val_accuracy: 0.8927
# Epoch 77/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1879 - accuracy: 0.9294 - val_loss: 0.3298 - val_accuracy: 0.8888
# Epoch 78/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1879 - accuracy: 0.9286 - val_loss: 0.3194 - val_accuracy: 0.8932
# Epoch 79/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1846 - accuracy: 0.9302 - val_loss: 0.3272 - val_accuracy: 0.8931
# Epoch 80/80
# 480/480 [==============================] - 2s 5ms/step - loss: 0.1866 - accuracy: 0.9303 - val_loss: 0.3227 - val_accuracy: 0.8907
# Epoch 1/50
# 300/300 [==============================] - 10s 31ms/step - loss: 0.7767 - accuracy: 0.7740 - val_loss: 0.5494 - val_accuracy: 0.8372
# Epoch 2/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.5033 - accuracy: 0.8534 - val_loss: 0.4381 - val_accuracy: 0.8692
# Epoch 3/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.4270 - accuracy: 0.8726 - val_loss: 0.3842 - val_accuracy: 0.8832
# Epoch 4/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.3950 - accuracy: 0.8784 - val_loss: 0.3777 - val_accuracy: 0.8823
# Epoch 5/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.3688 - accuracy: 0.8870 - val_loss: 0.3633 - val_accuracy: 0.8862
# Epoch 6/50
# 300/300 [==============================] - 14s 48ms/step - loss: 0.3497 - accuracy: 0.8933 - val_loss: 0.3453 - val_accuracy: 0.8943
# Epoch 7/50
# 300/300 [==============================] - 15s 50ms/step - loss: 0.3409 - accuracy: 0.8965 - val_loss: 0.3354 - val_accuracy: 0.8970
# Epoch 8/50
# 300/300 [==============================] - 16s 52ms/step - loss: 0.3266 - accuracy: 0.9026 - val_loss: 0.3541 - val_accuracy: 0.8894
# Epoch 9/50
# 300/300 [==============================] - 15s 51ms/step - loss: 0.3195 - accuracy: 0.9048 - val_loss: 0.3390 - val_accuracy: 0.8979
# Epoch 10/50
# 300/300 [==============================] - 12s 40ms/step - loss: 0.3105 - accuracy: 0.9076 - val_loss: 0.3142 - val_accuracy: 0.9057
# Epoch 11/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.3038 - accuracy: 0.9101 - val_loss: 0.3158 - val_accuracy: 0.9028
# Epoch 12/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2958 - accuracy: 0.9121 - val_loss: 0.3199 - val_accuracy: 0.9012
# Epoch 13/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2905 - accuracy: 0.9157 - val_loss: 0.3017 - val_accuracy: 0.9119
# Epoch 14/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2866 - accuracy: 0.9176 - val_loss: 0.3144 - val_accuracy: 0.9070
# Epoch 15/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2800 - accuracy: 0.9193 - val_loss: 0.3069 - val_accuracy: 0.9106
# Epoch 16/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2733 - accuracy: 0.9217 - val_loss: 0.3100 - val_accuracy: 0.9085
# Epoch 17/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2716 - accuracy: 0.9234 - val_loss: 0.3077 - val_accuracy: 0.9106
# Epoch 18/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2652 - accuracy: 0.9250 - val_loss: 0.3120 - val_accuracy: 0.9089
# Epoch 19/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2635 - accuracy: 0.9276 - val_loss: 0.3109 - val_accuracy: 0.9088
# Epoch 20/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2583 - accuracy: 0.9280 - val_loss: 0.3113 - val_accuracy: 0.9113
# Epoch 21/50
# 300/300 [==============================] - 13s 42ms/step - loss: 0.2560 - accuracy: 0.9292 - val_loss: 0.2963 - val_accuracy: 0.9118
# Epoch 22/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2511 - accuracy: 0.9325 - val_loss: 0.2991 - val_accuracy: 0.9123
# Epoch 23/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2463 - accuracy: 0.9336 - val_loss: 0.3010 - val_accuracy: 0.9143
# Epoch 24/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2450 - accuracy: 0.9337 - val_loss: 0.3059 - val_accuracy: 0.9124
# Epoch 25/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2404 - accuracy: 0.9354 - val_loss: 0.3023 - val_accuracy: 0.9146
# Epoch 26/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2386 - accuracy: 0.9377 - val_loss: 0.3123 - val_accuracy: 0.9099
# Epoch 27/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2336 - accuracy: 0.9394 - val_loss: 0.3010 - val_accuracy: 0.9157
# Epoch 28/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2330 - accuracy: 0.9396 - val_loss: 0.3176 - val_accuracy: 0.9118
# Epoch 29/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2281 - accuracy: 0.9413 - val_loss: 0.3016 - val_accuracy: 0.9146
# Epoch 30/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2261 - accuracy: 0.9428 - val_loss: 0.3099 - val_accuracy: 0.9144
# Epoch 31/50
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2234 - accuracy: 0.9431 - val_loss: 0.3038 - val_accuracy: 0.9163
# Epoch 32/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2178 - accuracy: 0.9459 - val_loss: 0.3015 - val_accuracy: 0.9164
# Epoch 33/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.2191 - accuracy: 0.9461 - val_loss: 0.3141 - val_accuracy: 0.9149
# Epoch 34/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2159 - accuracy: 0.9468 - val_loss: 0.3079 - val_accuracy: 0.9175
# Epoch 35/50
# 300/300 [==============================] - 12s 38ms/step - loss: 0.2097 - accuracy: 0.9493 - val_loss: 0.3023 - val_accuracy: 0.9199
# Epoch 36/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2108 - accuracy: 0.9501 - val_loss: 0.3073 - val_accuracy: 0.9191
# Epoch 37/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2068 - accuracy: 0.9506 - val_loss: 0.3245 - val_accuracy: 0.9161
# Epoch 38/50
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2096 - accuracy: 0.9500 - val_loss: 0.3099 - val_accuracy: 0.9196
# Epoch 39/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2009 - accuracy: 0.9535 - val_loss: 0.3094 - val_accuracy: 0.9183
# Epoch 40/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2019 - accuracy: 0.9540 - val_loss: 0.3145 - val_accuracy: 0.9169
# Epoch 41/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2039 - accuracy: 0.9525 - val_loss: 0.3128 - val_accuracy: 0.9184
# Epoch 42/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1939 - accuracy: 0.9566 - val_loss: 0.3170 - val_accuracy: 0.9174
# Epoch 43/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.1925 - accuracy: 0.9561 - val_loss: 0.3207 - val_accuracy: 0.9189
# Epoch 44/50
# 300/300 [==============================] - 11s 37ms/step - loss: 0.1949 - accuracy: 0.9563 - val_loss: 0.3123 - val_accuracy: 0.9210
# Epoch 45/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1940 - accuracy: 0.9558 - val_loss: 0.3203 - val_accuracy: 0.9213
# Epoch 46/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1946 - accuracy: 0.9564 - val_loss: 0.3249 - val_accuracy: 0.9180
# Epoch 47/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1866 - accuracy: 0.9594 - val_loss: 0.3324 - val_accuracy: 0.9158
# Epoch 48/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1834 - accuracy: 0.9614 - val_loss: 0.3338 - val_accuracy: 0.9181
# Epoch 49/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1855 - accuracy: 0.9600 - val_loss: 0.3257 - val_accuracy: 0.9211
# Epoch 50/50
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1847 - accuracy: 0.9597 - val_loss: 0.3382 - val_accuracy: 0.9172
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3435 - accuracy: 0.8889
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3629 - accuracy: 0.9121
# Точність моделі з оптимізатором SGD: 88.89%
# Точність моделі з оптимізатором Adam: 91.21%
